# %% [markdown]
# # Run the benchmark

# %%
# !python benchmark.py --frameworks tensorflow gensim originalc --file data/text8 --epochs 4 --batch_size 16 --workers 7 --size 100
# Out:
# python word2vec.py --train_data ../../data/text8 --embedding_size 100 --save_path_wordvectors ../../trainedVectors/tensorflow.vec --epochs_to_train 4 --window_size 5 --min_count 5 --learning_rate 0.025 --num_neg_samples5 --concurrent_steps 7 --subsample 0.001 --batch_size 16 --statistics_interval 5
# 0
# 2017-07-18 19:49:19.005705: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:49:19.005736: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:49:19.005750: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:49:19.005761: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:49:19.005773: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:49:19.130382: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:893] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2017-07-18 19:49:19.130612: I tensorflow/core/common_runtime/gpu/gpu_device.cc:940] Found device 0 with properties:
# name: GeForce GTX 1060
# major: 6 minor: 1 memoryClockRate (GHz) 1.6705
# pciBusID 0000:01:00.0
# Total memory: 2.94GiB
# Free memory: 2.61GiB
# 2017-07-18 19:49:19.130629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:961] DMA: 0
# 2017-07-18 19:49:19.130636: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   Y
# 2017-07-18 19:49:19.130646: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Creating TensorFlow device (/gpu:0) -> (device: 0, name: GeForce GTX 1060, pci bus id: 0000:01:00.0)
# 2017-07-18 19:49:21.261887: I word2vec_kernels.cc:200] Data file: ../../data/text8 contains 100000000 bytes, 17005207 words, 253854 unique words, 71290 unique frequent words.
# Data file:  ../../data/text8
# Vocab size:  71290  + UNK
# Words per epoch:  17005207
# Evaluating trained word vectors' quality for tensorflow...ec =     6722
# /usr/local/lib/python2.7/dist-packages/scipy/stats/stats.py:3016: RuntimeWarning: Mean of empty slice.
#   mx = x.mean()
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python2.7/dist-packages/scipy/stats/stats.py:3017: RuntimeWarning: Mean of empty slice.
#   my = y.mean()
# /usr/local/lib/python2.7/dist-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# python word2vec.py --train_data ../../data/text8 --embedding_size 100 --save_path_wordvectors ../../trainedVectors/tensorflow-gpu.vec --epochs_to_train 4 --window_size 5 --min_count 5 --learning_rate 0.025 --num_neg_samples5 --concurrent_steps 7 --subsample 0.001 --batch_size 16 --statistics_interval 5 --gpu 1
# 1
# 2017-07-18 20:37:48.126937: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 20:37:48.126956: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 20:37:48.126962: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 20:37:48.126968: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 20:37:48.126974: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 20:37:48.248631: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:893] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2017-07-18 20:37:48.248847: I tensorflow/core/common_runtime/gpu/gpu_device.cc:940] Found device 0 with properties:
# name: GeForce GTX 1060
# major: 6 minor: 1 memoryClockRate (GHz) 1.6705
# pciBusID 0000:01:00.0
# Total memory: 2.94GiB
# Free memory: 2.61GiB
# 2017-07-18 20:37:48.248863: I tensorflow/core/common_runtime/gpu/gpu_device.cc:961] DMA: 0
# 2017-07-18 20:37:48.248870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   Y
# 2017-07-18 20:37:48.248881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Creating TensorFlow device (/gpu:0) -> (device: 0, name: GeForce GTX 1060, pci bus id: 0000:01:00.0)
# 2017-07-18 20:37:50.091114: I word2vec_kernels.cc:200] Data file: ../../data/text8 contains 100000000 bytes, 17005207 words, 253854 unique words, 71290 unique frequent words.
# Data file:  ../../data/text8
# Vocab size:  71290  + UNK
# Words per epoch:  17005207
# 2017-07-18 20:38:22.616603: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 1776440 get requests, put_count=1776425 evicted_count=1000 eviction_rate=0.000562928 and unsatisfied allocation rate=0.00062766
# 2017-07-18 20:43:59.104716: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 22088295 get requests, put_count=22088277 evicted_count=11000 eviction_rate=0.000498002 and unsatisfied allocation rate=0.000503344
# 2017-07-18 20:49:13.550133: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 41066069 get requests, put_count=41066049 evicted_count=21000 eviction_rate=0.000511371 and unsatisfied allocation rate=0.000514293
# 2017-07-18 20:54:31.274268: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 60279312 get requests, put_count=60279298 evicted_count=31000 eviction_rate=0.000514273 and unsatisfied allocation rate=0.000516164
# 2017-07-18 20:59:51.947220: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 79905381 get requests, put_count=79905363 evicted_count=41000 eviction_rate=0.000513107 and unsatisfied allocation rate=0.000514584
# 2017-07-18 21:05:21.449589: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 100093800 get requests, put_count=100093780 evicted_count=51000 eviction_rate=0.000509522 and unsatisfied allocation rate=0.000510721
# 2017-07-18 21:10:31.310143: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 119093039 get requests, put_count=119093011 evicted_count=61000 eviction_rate=0.000512205 and unsatisfied allocation rate=0.000513279
# 2017-07-18 21:15:28.750378: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 137283519 get requests, put_count=137283502 evicted_count=71000 eviction_rate=0.000517178 and unsatisfied allocation rate=0.00051803
# 2017-07-18 21:20:20.710445: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 155144234 get requests, put_count=155144211 evicted_count=81000 eviction_rate=0.000522095 and unsatisfied allocation rate=0.000522888
# 2017-07-18 21:25:28.576936: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 173961591 get requests, put_count=173961576 evicted_count=91000 eviction_rate=0.000523104 and unsatisfied allocation rate=0.000523765
# 2017-07-18 21:30:39.557594: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 192814150 get requests, put_count=192814128 evicted_count=101000 eviction_rate=0.000523821 and unsatisfied allocation rate=0.000524453
# 2017-07-18 21:35:45.576984: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 211549924 get requests, put_count=211549908 evicted_count=111000 eviction_rate=0.000524699 and unsatisfied allocation rate=0.000525247
# 2017-07-18 21:40:58.706045: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 230730714 get requests, put_count=230730693 evicted_count=121000 eviction_rate=0.000524421 and unsatisfied allocation rate=0.000524945
# 2017-07-18 21:46:09.508082: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 249765885 get requests, put_count=249765863 evicted_count=131000 eviction_rate=0.000524491 and unsatisfied allocation rate=0.00052498
# 2017-07-18 21:51:25.584064: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 269129085 get requests, put_count=269129077 evicted_count=141000 eviction_rate=0.000523912 and unsatisfied allocation rate=0.000524313
# 2017-07-18 21:56:44.129138: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 288650991 get requests, put_count=288650973 evicted_count=151000 eviction_rate=0.000523123 and unsatisfied allocation rate=0.000523532
# 2017-07-18 22:01:59.303355: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 307950556 get requests, put_count=307950537 evicted_count=161000 eviction_rate=0.000522811 and unsatisfied allocation rate=0.000523198
# 2017-07-18 22:07:17.065701: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 327407490 get requests, put_count=327407472 evicted_count=171000 eviction_rate=0.000522285 and unsatisfied allocation rate=0.000522645
# 2017-07-18 22:12:30.664571: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 346607647 get requests, put_count=346607629 evicted_count=181000 eviction_rate=0.000522204 and unsatisfied allocation rate=0.000522545
# 2017-07-18 22:17:47.914196: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 366030781 get requests, put_count=366030762 evicted_count=191000 eviction_rate=0.000521814 and unsatisfied allocation rate=0.000522139
# 2017-07-18 22:23:11.259247: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 385669373 get requests, put_count=385669355 evicted_count=201000 eviction_rate=0.000521172 and unsatisfied allocation rate=0.000521478
# 2017-07-18 22:28:22.924409: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 404760141 get requests, put_count=404760123 evicted_count=211000 eviction_rate=0.000521296 and unsatisfied allocation rate=0.000521588
# 2017-07-18 22:33:25.483145: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 423293889 get requests, put_count=423293877 evicted_count=221000 eviction_rate=0.000522096 and unsatisfied allocation rate=0.00052236
# 2017-07-18 22:38:45.072188: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 442864079 get requests, put_count=442864058 evicted_count=231000 eviction_rate=0.000521605 and unsatisfied allocation rate=0.000521878
# 2017-07-18 22:43:43.447186: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 461129887 get requests, put_count=461129870 evicted_count=241000 eviction_rate=0.000522629 and unsatisfied allocation rate=0.000522883
# 2017-07-18 22:48:46.468834: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 479684846 get requests, put_count=479684833 evicted_count=251000 eviction_rate=0.00052326 and unsatisfied allocation rate=0.000523496
# 2017-07-18 22:53:46.603192: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 498072047 get requests, put_count=498072030 evicted_count=261000 eviction_rate=0.000524021 and unsatisfied allocation rate=0.000524255
# 2017-07-18 22:59:03.385551: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 517467538 get requests, put_count=517467525 evicted_count=271000 eviction_rate=0.000523704 and unsatisfied allocation rate=0.000523923
# 2017-07-18 23:04:14.816915: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 536544576 get requests, put_count=536544557 evicted_count=281000 eviction_rate=0.000523722 and unsatisfied allocation rate=0.000523943
# 2017-07-18 23:09:44.810481: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 556582090 get requests, put_count=556582073 evicted_count=291000 eviction_rate=0.000522834 and unsatisfied allocation rate=0.000523044
# 2017-07-18 23:15:09.276685: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 576448665 get requests, put_count=576448646 evicted_count=301000 eviction_rate=0.000522163 and unsatisfied allocation rate=0.000522369
# 2017-07-18 23:19:57.409484: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 594090566 get requests, put_count=594090552 evicted_count=311000 eviction_rate=0.000523489 and unsatisfied allocation rate=0.000523681
# 2017-07-18 23:24:53.339188: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 612206761 get requests, put_count=612206738 evicted_count=321000 eviction_rate=0.000524333 and unsatisfied allocation rate=0.000524534
# 2017-07-18 23:30:09.192661: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 631542705 get requests, put_count=631542682 evicted_count=331000 eviction_rate=0.000524113 and unsatisfied allocation rate=0.000524308
# 2017-07-18 23:35:12.478387: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 650122232 get requests, put_count=650122205 evicted_count=341000 eviction_rate=0.000524517 and unsatisfied allocation rate=0.000524712
# 2017-07-18 23:40:28.438118: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 669467848 get requests, put_count=669467827 evicted_count=351000 eviction_rate=0.000524297 and unsatisfied allocation rate=0.000524478
# 2017-07-18 23:45:24.327501: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 687589559 get requests, put_count=687589546 evicted_count=361000 eviction_rate=0.000525023 and unsatisfied allocation rate=0.000525187
# 2017-07-18 23:50:20.396112: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 705725495 get requests, put_count=705725481 evicted_count=371000 eviction_rate=0.0005257 and unsatisfied allocation rate=0.000525862
# 2017-07-18 23:55:24.332456: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 724337659 get requests, put_count=724337633 evicted_count=381000 eviction_rate=0.000525998 and unsatisfied allocation rate=0.000526172
# Evaluating trained word vectors' quality for tensorflow-gpu...     2408
# python gensim_word2vec.py --file ../../data/text8 --size 100 --outputpath ../../trainedVectors/ --iter 4 --window 5 --min_count 5 --alpha 0.025 --negative 5 --sg 1 --workers 7 --sample 0.001
# {'workers': 7, 'negative': 5, 'iter': 4, 'sample': 0.001, 'window': 5, 'min_count': 5, 'alpha': 0.025, 'sg': 1, 'size': 100}
# 2017-07-18 23:59:31,367 : INFO : collecting all words and their counts
# 2017-07-18 23:59:31,368 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-07-18 23:59:35,504 : INFO : collected 253854 word types from a corpus of 17005207 raw words and 1701 sentences
# 2017-07-18 23:59:35,505 : INFO : Loading a fresh vocabulary
# 2017-07-18 23:59:35,752 : INFO : min_count=5 retains 71290 unique words (28% of original 253854, drops 182564)
# 2017-07-18 23:59:35,753 : INFO : min_count=5 leaves 16718844 word corpus (98% of original 17005207, drops 286363)
# 2017-07-18 23:59:35,877 : INFO : deleting the raw counts dictionary of 253854 items
# 2017-07-18 23:59:35,900 : INFO : sample=0.001 downsamples 38 most-common words
# 2017-07-18 23:59:35,900 : INFO : downsampling leaves estimated 12506280 word corpus (74.8% of prior 16718844)
# 2017-07-18 23:59:35,900 : INFO : estimated required memory for 71290 words and 100 dimensions: 92677000 bytes
# 2017-07-18 23:59:36,078 : INFO : resetting layer weights
# 2017-07-18 23:59:36,627 : INFO : training model with 7 workers on 71290 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2017-07-18 23:59:37,637 : INFO : PROGRESS: at 1.18% examples, 583153 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:38,664 : INFO : PROGRESS: at 2.45% examples, 599738 words/s, in_qsize 13, out_qsize 0
# 2017-07-18 23:59:39,661 : INFO : PROGRESS: at 3.70% examples, 606819 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:40,668 : INFO : PROGRESS: at 4.97% examples, 612015 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:41,682 : INFO : PROGRESS: at 6.23% examples, 615105 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:42,695 : INFO : PROGRESS: at 7.48% examples, 616897 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:43,703 : INFO : PROGRESS: at 8.70% examples, 616864 words/s, in_qsize 13, out_qsize 1
# 2017-07-18 23:59:44,717 : INFO : PROGRESS: at 9.95% examples, 617068 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:45,731 : INFO : PROGRESS: at 11.18% examples, 616058 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:46,745 : INFO : PROGRESS: at 12.43% examples, 616728 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 23:59:47,754 : INFO : PROGRESS: at 13.67% examples, 616434 words/s, in_qsize 12, out_qsize 1
# 2017-07-18 23:59:48,782 : INFO : PROGRESS: at 14.93% examples, 616452 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:49,797 : INFO : PROGRESS: at 16.18% examples, 616439 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:50,808 : INFO : PROGRESS: at 17.43% examples, 616673 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:51,814 : INFO : PROGRESS: at 18.67% examples, 616713 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:52,829 : INFO : PROGRESS: at 19.94% examples, 616458 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:53,832 : INFO : PROGRESS: at 21.19% examples, 616688 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 23:59:54,832 : INFO : PROGRESS: at 22.43% examples, 616857 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:55,845 : INFO : PROGRESS: at 23.69% examples, 616929 words/s, in_qsize 13, out_qsize 0
# 2017-07-18 23:59:56,847 : INFO : PROGRESS: at 24.96% examples, 617422 words/s, in_qsize 13, out_qsize 0
# 2017-07-18 23:59:57,857 : INFO : PROGRESS: at 26.21% examples, 617489 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 23:59:58,878 : INFO : PROGRESS: at 27.48% examples, 617476 words/s, in_qsize 13, out_qsize 0
# 2017-07-18 23:59:59,890 : INFO : PROGRESS: at 28.75% examples, 617718 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:00,897 : INFO : PROGRESS: at 29.98% examples, 617541 words/s, in_qsize 14, out_qsize 1
# 2017-07-19 00:00:01,901 : INFO : PROGRESS: at 31.23% examples, 617890 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:02,907 : INFO : PROGRESS: at 32.48% examples, 618406 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:03,919 : INFO : PROGRESS: at 33.72% examples, 618323 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:04,927 : INFO : PROGRESS: at 34.96% examples, 618459 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:05,937 : INFO : PROGRESS: at 36.20% examples, 618330 words/s, in_qsize 13, out_qsize 1
# 2017-07-19 00:00:06,966 : INFO : PROGRESS: at 37.43% examples, 617933 words/s, in_qsize 14, out_qsize 2
# 2017-07-19 00:00:07,975 : INFO : PROGRESS: at 38.70% examples, 618182 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:08,982 : INFO : PROGRESS: at 39.93% examples, 618217 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:09,991 : INFO : PROGRESS: at 41.17% examples, 617961 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:11,011 : INFO : PROGRESS: at 42.43% examples, 618036 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:12,019 : INFO : PROGRESS: at 43.67% examples, 617998 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:13,022 : INFO : PROGRESS: at 44.94% examples, 618084 words/s, in_qsize 10, out_qsize 0
# 2017-07-19 00:00:14,023 : INFO : PROGRESS: at 46.16% examples, 617795 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:15,025 : INFO : PROGRESS: at 47.41% examples, 617976 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:16,035 : INFO : PROGRESS: at 48.68% examples, 618037 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:17,047 : INFO : PROGRESS: at 49.93% examples, 618111 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:18,045 : INFO : PROGRESS: at 51.16% examples, 618003 words/s, in_qsize 14, out_qsize 1
# 2017-07-19 00:00:19,057 : INFO : PROGRESS: at 52.44% examples, 618049 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:20,063 : INFO : PROGRESS: at 53.69% examples, 618050 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:21,076 : INFO : PROGRESS: at 54.95% examples, 618177 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:22,084 : INFO : PROGRESS: at 56.19% examples, 618152 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:23,112 : INFO : PROGRESS: at 57.42% examples, 617971 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:24,116 : INFO : PROGRESS: at 58.64% examples, 617903 words/s, in_qsize 14, out_qsize 1
# 2017-07-19 00:00:25,122 : INFO : PROGRESS: at 59.91% examples, 618198 words/s, in_qsize 12, out_qsize 0
# 2017-07-19 00:00:26,126 : INFO : PROGRESS: at 61.14% examples, 618155 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:27,127 : INFO : PROGRESS: at 62.38% examples, 618209 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:28,135 : INFO : PROGRESS: at 63.59% examples, 618112 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:29,132 : INFO : PROGRESS: at 64.84% examples, 618238 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:30,138 : INFO : PROGRESS: at 66.11% examples, 618445 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:31,138 : INFO : PROGRESS: at 67.33% examples, 618324 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:32,145 : INFO : PROGRESS: at 68.58% examples, 618435 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:33,158 : INFO : PROGRESS: at 69.86% examples, 618341 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:34,166 : INFO : PROGRESS: at 71.13% examples, 618611 words/s, in_qsize 12, out_qsize 0
# 2017-07-19 00:00:35,167 : INFO : PROGRESS: at 72.35% examples, 618479 words/s, in_qsize 13, out_qsize 1
# 2017-07-19 00:00:36,191 : INFO : PROGRESS: at 73.60% examples, 618240 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:37,198 : INFO : PROGRESS: at 74.87% examples, 618414 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:38,207 : INFO : PROGRESS: at 76.07% examples, 618131 words/s, in_qsize 13, out_qsize 2
# 2017-07-19 00:00:39,215 : INFO : PROGRESS: at 77.35% examples, 618118 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:40,230 : INFO : PROGRESS: at 78.60% examples, 618032 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:41,255 : INFO : PROGRESS: at 79.86% examples, 618007 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:42,262 : INFO : PROGRESS: at 81.08% examples, 617884 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:43,267 : INFO : PROGRESS: at 82.32% examples, 617924 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:44,279 : INFO : PROGRESS: at 83.55% examples, 617934 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:45,292 : INFO : PROGRESS: at 84.80% examples, 617969 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:46,304 : INFO : PROGRESS: at 86.04% examples, 617867 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:47,305 : INFO : PROGRESS: at 87.26% examples, 617810 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:48,328 : INFO : PROGRESS: at 88.52% examples, 617853 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:49,342 : INFO : PROGRESS: at 89.79% examples, 617962 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:50,352 : INFO : PROGRESS: at 91.03% examples, 617999 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:51,354 : INFO : PROGRESS: at 92.28% examples, 618096 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:52,362 : INFO : PROGRESS: at 93.52% examples, 618114 words/s, in_qsize 12, out_qsize 0
# 2017-07-19 00:00:53,364 : INFO : PROGRESS: at 94.80% examples, 618142 words/s, in_qsize 13, out_qsize 0
# 2017-07-19 00:00:54,385 : INFO : PROGRESS: at 96.05% examples, 618005 words/s, in_qsize 14, out_qsize 1
# 2017-07-19 00:00:55,392 : INFO : PROGRESS: at 97.31% examples, 618134 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:56,392 : INFO : PROGRESS: at 98.56% examples, 618167 words/s, in_qsize 14, out_qsize 0
# 2017-07-19 00:00:57,416 : INFO : PROGRESS: at 99.81% examples, 618065 words/s, in_qsize 13, out_qsize 1
# 2017-07-19 00:00:57,491 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2017-07-19 00:00:57,501 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2017-07-19 00:00:57,515 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2017-07-19 00:00:57,516 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-07-19 00:00:57,519 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-07-19 00:00:57,520 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-07-19 00:00:57,529 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-07-19 00:00:57,529 : INFO : training on 68020828 raw words (50023147 effective words) took 80.9s, 618328 effective words/s
# 2017-07-19 00:00:57,529 : INFO : storing 71290x100 projection weights into ../../trainedVectors/gensim.vec
# Evaluating trained word vectors' quality for gensim...
# ./word2vec -train ../../data/text8 -size 100 -output ../../trainedVectors/originalc.vec --iter 4 -window 5 -min-count 5 -alpha 0.025 -negative 5 -cbow 0 -threads 7 -sample 0.001 -binary 0
# Starting training using file ../../data/text8
# Vocab size: 71291
# Words in train file: 16718843
# Alpha: 0.000002  Progress: 100.02%  Words/thread/sec: 107.25k  Evaluating trained word vectors' quality for originalc...
# Trained all frameworks!
# Reports generated!
# Finished running the benchmark!!!

# %% [markdown]
# ## System Information

# %%
with open('report/system-info.txt', 'r') as f:
    print f.read()
# Out:
# CPU INFO
# Model name:Intel(R) Core(TM) i7-7700HQ CPU @ 2.80GHz , Architecture:x86_64 , CPU(s):8 , MemTotal:16384112 kB ,
# GPU INFO
# Model Name : GeForce GTX 1060, Total FB Memory : 3011 MiB

# %% [markdown]
# ## Plot benchamrk reports

# %%
# !python generate_plots.py
# Out:
# Plotting reports...
# ('tensorflow', 'tensorflow-gpu', 'gensim', 'originalc')
# Plotted Time-Memory Report.
# Plotted 'Word Pairs Evaluation' Report.
# Plotted 'Analogies Task(Question&Answers)' Report.
# Finished plotting the benchmark!!!

# %% [markdown]
# # Display generated graphics

# %%
from IPython.core.display import Image, display_jpeg

# %% [markdown]
# Time to train(in seconds) and peak memory(in MiB) results

# %%
display_jpeg(Image(filename='./report/time&peakmemoryFig.jpg', width=800, unconfined=False))

# %% [markdown]
# Results of evaluation on the popular **Word Similarities** task. This task measures how well the notion of word similarity according to humans is captured by the word vector representations. Two lists are obtained by sorting the word pairs according to human similarity and vector-space similarity. Spearman’s correlation/rho between these
# ranked lists is the used to signify how well the vector space agrees with human judgement.

# %%
display_jpeg(Image(filename='./report/word-pairs-report-fig.jpg', unconfined=False))

# %% [markdown]
# Results of evaluation on the popular **Word Analogy** task. The aim of this task is to find the missing word b' in the relation: a is to a' as b is to b'. In other words we look at the most similar word vector to b' (= a' + b - a) and compare it with the human analogy and report the accuracy.

# %%
display_jpeg(Image(filename='./report/question-answer-fig.jpg', unconfined=False))
