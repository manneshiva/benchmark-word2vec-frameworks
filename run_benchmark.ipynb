# %%
# !python benchmark.py --frameworks gensim originalc --file data/text8 --epochs 1 --batch_size 2048 --workers 7
# Out:
# python gensim_word2vec.py --file ../../data/text8 --size 100 --outputpath ../../trainedVectors/ --iter 1 --window 5 --min_count 5 --alpha 0.025 --negative 5 --sg 1 --workers 7 --sample 0.001
# {'workers': 7, 'negative': 5, 'iter': 1, 'sample': 0.001, 'window': 5, 'min_count': 5, 'alpha': 0.025, 'sg': 1, 'size': 100}
# 2017-06-29 21:43:42,603 : INFO : collecting all words and their counts
# 2017-06-29 21:43:42,604 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-06-29 21:43:46,825 : INFO : collected 253854 word types from a corpus of 17005207 raw words and 1701 sentences
# 2017-06-29 21:43:46,825 : INFO : Loading a fresh vocabulary
# 2017-06-29 21:43:47,071 : INFO : min_count=5 retains 71290 unique words (28% of original 253854, drops 182564)
# 2017-06-29 21:43:47,071 : INFO : min_count=5 leaves 16718844 word corpus (98% of original 17005207, drops 286363)
# 2017-06-29 21:43:47,185 : INFO : deleting the raw counts dictionary of 253854 items
# ...

# %%
from IPython.core.display import Image, display_jpeg

# %%
display_jpeg(Image(filename='./report/time&peakmemoryFig.jpg', width=800, unconfined=False))

# %%
display_jpeg(Image(filename='./report/word-pairs-report-fig.jpg', unconfined=False))

# %%
display_jpeg(Image(filename='./report/question-answer-fig.jpg', unconfined=False))
