# %% [markdown]
# # Run the benchmark

# %%
# !python benchmark.py --frameworks gensim tensorflow originalc --file data/text8 --epochs 1 --batch_size 512 --workers 7 --size 10
# Out:
# python gensim_word2vec.py --file ../../data/text8 --size 10 --outputpath ../../trainedVectors/ --iter 1 --window 5 --min_count 5 --alpha 0.025 --negative 5 --sg 1 --workers 7 --sample 0.001
# {'workers': 7, 'negative': 5, 'iter': 1, 'sample': 0.001, 'window': 5, 'min_count': 5, 'alpha': 0.025, 'sg': 1, 'size': 10}
# 2017-07-18 18:59:34,532 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2017-07-18 18:59:34,532 : INFO : collecting all words and their counts
# 2017-07-18 18:59:34,533 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-07-18 18:59:38,685 : INFO : collected 253854 word types from a corpus of 17005207 raw words and 1701 sentences
# 2017-07-18 18:59:38,685 : INFO : Loading a fresh vocabulary
# 2017-07-18 18:59:38,929 : INFO : min_count=5 retains 71290 unique words (28% of original 253854, drops 182564)
# 2017-07-18 18:59:38,929 : INFO : min_count=5 leaves 16718844 word corpus (98% of original 17005207, drops 286363)
# 2017-07-18 18:59:39,052 : INFO : deleting the raw counts dictionary of 253854 items
# 2017-07-18 18:59:39,077 : INFO : sample=0.001 downsamples 38 most-common words
# 2017-07-18 18:59:39,077 : INFO : downsampling leaves estimated 12506280 word corpus (74.8% of prior 16718844)
# 2017-07-18 18:59:39,077 : INFO : estimated required memory for 71290 words and 10 dimensions: 41348200 bytes
# 2017-07-18 18:59:39,253 : INFO : resetting layer weights
# 2017-07-18 18:59:39,768 : INFO : training model with 7 workers on 71290 vocabulary and 10 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2017-07-18 18:59:40,774 : INFO : PROGRESS: at 7.94% examples, 981422 words/s, in_qsize 13, out_qsize 0
# 2017-07-18 18:59:41,778 : INFO : PROGRESS: at 16.23% examples, 1004203 words/s, in_qsize 13, out_qsize 0
# 2017-07-18 18:59:42,783 : INFO : PROGRESS: at 24.40% examples, 1009870 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 18:59:43,784 : INFO : PROGRESS: at 32.45% examples, 1012024 words/s, in_qsize 13, out_qsize 0
# 2017-07-18 18:59:44,808 : INFO : PROGRESS: at 40.56% examples, 1009956 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 18:59:45,811 : INFO : PROGRESS: at 48.74% examples, 1012481 words/s, in_qsize 10, out_qsize 0
# 2017-07-18 18:59:46,819 : INFO : PROGRESS: at 56.85% examples, 1011311 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 18:59:47,834 : INFO : PROGRESS: at 65.02% examples, 1010998 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 18:59:48,838 : INFO : PROGRESS: at 73.25% examples, 1013224 words/s, in_qsize 12, out_qsize 0
# 2017-07-18 18:59:49,849 : INFO : PROGRESS: at 81.36% examples, 1010383 words/s, in_qsize 14, out_qsize 1
# 2017-07-18 18:59:50,854 : INFO : PROGRESS: at 89.59% examples, 1011687 words/s, in_qsize 14, out_qsize 0
# 2017-07-18 18:59:51,857 : INFO : PROGRESS: at 97.82% examples, 1012234 words/s, in_qsize 13, out_qsize 0
# 2017-07-18 18:59:52,080 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2017-07-18 18:59:52,083 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2017-07-18 18:59:52,087 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2017-07-18 18:59:52,098 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-07-18 18:59:52,104 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-07-18 18:59:52,109 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-07-18 18:59:52,110 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-07-18 18:59:52,110 : INFO : training on 17005207 raw words (12505411 effective words) took 12.3s, 1013397 effective words/s
# 2017-07-18 18:59:52,110 : INFO : storing 71290x10 projection weights into ../../trainedVectors/gensim.vec
# Evaluating trained word vectors' quality for gensim...
# /usr/local/lib/python2.7/dist-packages/scipy/stats/stats.py:3016: RuntimeWarning: Mean of empty slice.
#   mx = x.mean()
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python2.7/dist-packages/scipy/stats/stats.py:3017: RuntimeWarning: Mean of empty slice.
#   my = y.mean()
# /usr/local/lib/python2.7/dist-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# python word2vec.py --train_data ../../data/text8 --embedding_size 10 --save_path_wordvectors ../../trainedVectors/tensorflow.vec --epochs_to_train 1 --window_size 5 --min_count 5 --learning_rate 0.025 --num_neg_samples5 --concurrent_steps 7 --subsample 0.001 --batch_size 512 --statistics_interval 5
# 0
# 2017-07-18 19:00:29.248959: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:00:29.248978: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:00:29.248985: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:00:29.248991: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:00:29.248996: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:00:29.369871: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:893] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2017-07-18 19:00:29.370087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:940] Found device 0 with properties:
# name: GeForce GTX 1060
# major: 6 minor: 1 memoryClockRate (GHz) 1.6705
# pciBusID 0000:01:00.0
# Total memory: 2.94GiB
# Free memory: 2.45GiB
# 2017-07-18 19:00:29.370104: I tensorflow/core/common_runtime/gpu/gpu_device.cc:961] DMA: 0
# 2017-07-18 19:00:29.370111: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   Y
# 2017-07-18 19:00:29.370122: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Creating TensorFlow device (/gpu:0) -> (device: 0, name: GeForce GTX 1060, pci bus id: 0000:01:00.0)
# 2017-07-18 19:00:31.278498: I word2vec_kernels.cc:200] Data file: ../../data/text8 contains 100000000 bytes, 17005207 words, 253854 unique words, 71290 unique frequent words.
# Data file:  ../../data/text8
# Vocab size:  71290  + UNK
# Words per epoch:  17005207
# Evaluating trained word vectors' quality for tensorflow...ec =    58958
# python word2vec.py --train_data ../../data/text8 --embedding_size 10 --save_path_wordvectors ../../trainedVectors/tensorflow-gpu.vec --epochs_to_train 1 --window_size 5 --min_count 5 --learning_rate 0.025 --num_neg_samples5 --concurrent_steps 7 --subsample 0.001 --batch_size 512 --statistics_interval 5 --gpu 1
# 1
# 2017-07-18 19:03:24.779400: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:03:24.779419: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:03:24.779427: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:03:24.779433: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:03:24.779440: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# 2017-07-18 19:03:24.896568: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:893] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2017-07-18 19:03:24.896784: I tensorflow/core/common_runtime/gpu/gpu_device.cc:940] Found device 0 with properties:
# name: GeForce GTX 1060
# major: 6 minor: 1 memoryClockRate (GHz) 1.6705
# pciBusID 0000:01:00.0
# Total memory: 2.94GiB
# Free memory: 2.45GiB
# 2017-07-18 19:03:24.896801: I tensorflow/core/common_runtime/gpu/gpu_device.cc:961] DMA: 0
# 2017-07-18 19:03:24.896808: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   Y
# 2017-07-18 19:03:24.896819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Creating TensorFlow device (/gpu:0) -> (device: 0, name: GeForce GTX 1060, pci bus id: 0000:01:00.0)
# 2017-07-18 19:03:26.800607: I word2vec_kernels.cc:200] Data file: ../../data/text8 contains 100000000 bytes, 17005207 words, 253854 unique words, 71290 unique frequent words.
# Data file:  ../../data/text8
# Vocab size:  71290  + UNK
# Words per epoch:  17005207
# 2017-07-18 19:03:55.055931: I tensorflow/core/common_runtime/gpu/pool_allocator.cc:247] PoolAllocator: After 1515191 get requests, put_count=1515162 evicted_count=1000 eviction_rate=0.000659995 and unsatisfied allocation rate=0.000745121
# Evaluating trained word vectors' quality for tensorflow-gpu...    76352
# ./word2vec -train ../../data/text8 -size 10 -output ../../trainedVectors/originalc.vec --iter 1 -window 5 -min-count 5 -alpha 0.025 -negative 5 -cbow 0 -threads 7 -sample 0.001 -binary 0
# Starting training using file ../../data/text8
# Vocab size: 71291
# Words in train file: 16718843
# Alpha: 0.000002  Progress: 100.03%  Words/thread/sec: 115.70k  Evaluating trained word vectors' quality for originalc...
# Trained all frameworks!
# Reports generated!
# Finished running the benchmark!!!

# %% [markdown]
# ## System Information

# %%
with open('report/system-info.txt', 'r') as f:
    print f.read()
# Out:
# CPU INFO
# Model name:Intel(R) Core(TM) i7-7700HQ CPU @ 2.80GHz , Architecture:x86_64 , CPU(s):8 , MemTotal:16384112 kB ,
# GPU INFO
# Model Name : GeForce GTX 1060, Total FB Memory : 3011 MiB

# %% [markdown]
# ## Plot benchamrk reports

# %%
# !python generate_plots.py
# Out:
# Plotting reports...
# ('gensim', 'tensorflow', 'tensorflow-gpu', 'originalc')
# Plotted Time-Memory Report.
# Plotted 'Word Pairs Evaluation' Report.
# Plotted 'Analogies Task(Question&Answers)' Report.
# Finished plotting the benchmark!!!

# %% [markdown]
# # Display generated graphics

# %%
from IPython.core.display import Image, display_jpeg

# %% [markdown]
# Time to train(in seconds) and peak memory(in MiB) results

# %%
display_jpeg(Image(filename='./report/time&peakmemoryFig.jpg', width=800, unconfined=False))

# %% [markdown]
# Results of evaluation on the popular **Word Similarities** task. This task measures how well the notion of word similarity according to humans is captured by the word vector representations. Two lists are obtained by sorting the word pairs according to human similarity and vector-space similarity. Spearman’s correlation/rho between these
# ranked lists is the used to signify how well the vector space agrees with human judgement.

# %%
display_jpeg(Image(filename='./report/word-pairs-report-fig.jpg', unconfined=False))

# %% [markdown]
# Results of evaluation on the popular **Word Analogy** task. The aim of this task is to find the missing word b' in the relation: a is to a' as b is to b'. In other words we look at the most similar word vector to b' (= a' + b - a) and compare it with the human analogy and report the accuracy.

# %%
display_jpeg(Image(filename='./report/question-answer-fig.jpg', unconfined=False))
